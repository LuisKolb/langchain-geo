# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import GraphSparqlQAChain
from langchain.graphs import RdfGraph

# %%
graph = RdfGraph(
    source_file="data/rdf/conceptsAndRelations.ttl",
    serialization="ttl",
    standard="rdf",
    local_copy="rdfGraph/local.ttl",
)

# %%
graph.load_schema()

# %%
print(graph.get_schema)
# Out:
# In the following, each IRI is followed by the local name and optionally its description in parentheses.
# The RDF graph supports the following node types:
# <http://www.w3.org/2004/02/skos/core#Concept> (Concept, None), <http://purl.org/dc/terms/BibliographicResource> (BibliographicResource, None), <http://www.w3.org/2004/02/skos/core#ConceptScheme> (ConceptScheme, None), <http://www.w3.org/2004/02/skos/core#Collection> (Collection, None)
# The RDF graph supports the following relationships:
# <http://purl.org/dc/terms/source> (source, None), <http://gk50.geolba.ac.at/hasUnit> (hasUnit, None), <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> (type, None), <http://gk50.geolba.ac.at/lithology> (lithology, None), <http://gk50.geolba.ac.at/geolUnit> (geolUnit, None), <http://gk50.geolba.ac.at/geolUnitType> (geolUnitType, None), <http://gk50.geolba.ac.at/proportion> (proportion, None), <http://gk50.geolba.ac.at/onMap> (onMap, None), <http://gk50.geolba.ac.at/role> (role, None), <http://gk50.geolba.ac.at/isPartOf> (isPartOf, None), <http://www.w3.org/2004/02/skos/core#broader> (broader, None), <http://purl.org/dc/terms/date> (date, None), <http://gk50.geolba.ac.at/tectUnit> (tectUnit, None), <http://www.w3.org/2004/02/skos/core#definition> (definition, None), <https://schema.org/mainEntityOfPage> (mainEntityOfPage, None), <http://gk50.geolba.ac.at/mainAge> (mainAge, None), <http://www.w3.org/2004/02/skos/core#prefLabel> (prefLabel, None), <http://gk50.geolba.ac.at/hasPart> (hasPart, None), <http://gk50.geolba.ac.at/hasEvent> (hasEvent, None), <http://resource.geolba.ac.at/schema/thes#status> (status, None), <http://purl.org/dc/terms/creator> (creator, None), <http://gk50.geolba.ac.at/mainLithology> (mainLithology, None), <http://gk50.geolba.ac.at/sideLithology> (sideLithology, None), <http://purl.org/dc/terms/bibliographicCitation> (bibliographicCitation, None), <http://purl.org/dc/terms/references> (references, None), <http://gk50.geolba.ac.at/eventProcess> (eventProcess, None), <http://purl.org/dc/terms/identifier> (identifier, None), <http://gk50.geolba.ac.at/eventEnvironment> (eventEnvironment, None), <http://www.w3.org/2004/02/skos/core#related> (related, None), <http://gk50.geolba.ac.at/isEventOf> (isEventOf, None), <http://www.w3.org/2004/02/skos/core#altLabel> (altLabel, None), <http://resource.geolba.ac.at/schema/GBA/DNS> (DNS, None), <http://purl.org/dc/terms/contributor> (contributor, None), <http://www.w3.org/2004/02/skos/core#member> (member, None), <http://purl.org/dc/terms/created> (created, None), <http://gk50.geolba.ac.at/olderAge> (olderAge, None), <http://purl.org/dc/terms/modified> (modified, None), <http://resource.geolba.ac.at/schema/thes#mapViewer> (mapViewer, None), <http://www.w3.org/2004/02/skos/core#narrower> (narrower, None), <http://gk50.geolba.ac.at/youngerAge> (youngerAge, None), <http://www.w3.org/2004/02/skos/core#scopeNote> (scopeNote, None), <http://resource.geolba.ac.at/schema/GBA/PDF_download> (PDF_download, None), <http://purl.org/dc/terms/hasVersion> (hasVersion, None), <http://purl.org/dc/terms/isReferencedBy> (isReferencedBy, None), <http://www.w3.org/2004/02/skos/core#hiddenLabel> (hiddenLabel, None), <http://www.w3.org/2004/02/skos/core#broadMatch> (broadMatch, None), <http://www.w3.org/2004/02/skos/core#narrowMatch> (narrowMatch, None), <http://www.w3.org/2004/02/skos/core#exactMatch> (exactMatch, None), <http://purl.org/dc/terms/description> (description, None), <http://dbpedia.org/ontology/colourHexCode> (colourHexCode, None), <http://resource.geolba.ac.at/PoolParty/schema/GBA/DataViewer> (DataViewer, None), <http://resource.geolba.ac.at/PoolParty/schema/GBA/GBA_Status> (GBA_Status, None), <http://www.w3.org/2004/02/skos/core#notation> (notation, None), <http://xmlns.com/foaf/0.1/depiction> (depiction, None), <http://gk50.geolba.ac.at/protolith> (protolith, None), <http://www.w3.org/2000/01/rdf-schema#label> (label, None), <http://www.w3.org/2003/01/geo/wgs84_pos#lat> (lat, None), <http://www.w3.org/2004/02/skos/core#topConceptOf> (topConceptOf, None), <http://purl.org/dc/terms/replaces> (replaces, None), <http://www.w3.org/2004/02/skos/core#example> (example, None), <http://www.w3.org/2004/02/skos/core#note> (note, None), <http://www.w3.org/2004/02/skos/core#hasTopConcept> (hasTopConcept, None), <http://resource.geolba.ac.at/schema/thes#isOlderThan> (isOlderThan, None), <http://www.w3.org/2003/01/geo/wgs84_pos#lat_long> (lat_long, None), <http://resource.geolba.ac.at/schema/ ...

# %%
from dotenv import load_dotenv
load_dotenv()
chain = GraphSparqlQAChain.from_llm(
    ChatOpenAI(temperature=0), graph=graph, verbose=True
)

# %%
chain.run("Tell me the name of the maps which have formic rock in them.")
# Out:
# > Entering new GraphSparqlQAChain chain...
# Identified intent:
# UPDATE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 chain.run("Tell me the name of the maps which have formic rock in them.")
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\base.py:475, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     473     if len(args) != 1:
#     474         raise ValueError("`run` supports only one positional argument.")
# --> 475     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     476         _output_key
#     477     ]
#     479 if kwargs and not args:
#     480     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     481         _output_key
#     482     ]
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\base.py:282, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     280 except (KeyboardInterrupt, Exception) as e:
#     281     run_manager.on_chain_error(e)
# --> 282     raise e
#     283 run_manager.on_chain_end(outputs)
#     284 final_outputs: Dict[str, Any] = self.prep_outputs(
#     285     inputs, outputs, return_only_outputs
#     286 )
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\base.py:276, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     270 run_manager = callback_manager.on_chain_start(
#     271     dumpd(self),
#     272     inputs,
#     273 )
#     274 try:
#     275     outputs = (
# --> 276         self._call(inputs, run_manager=run_manager)
#     277         if new_arg_supported
#     278         else self._call(inputs)
#     279     )
#     280 except (KeyboardInterrupt, Exception) as e:
#     281     run_manager.on_chain_error(e)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\graph_qa\sparql.py:103, in GraphSparqlQAChain._call(self, inputs, run_manager)
#     100 _run_manager.on_text("Identified intent:", end="\n", verbose=self.verbose)
#     101 _run_manager.on_text(intent, color="green", end="\n", verbose=self.verbose)
# --> 103 generated_sparql = sparql_generation_chain.run(
#     104     {"prompt": prompt, "schema": self.graph.get_schema}, callbacks=callbacks
#     105 )
#     107 _run_manager.on_text("Generated SPARQL:", end="\n", verbose=self.verbose)
#     108 _run_manager.on_text(
#     109     generated_sparql, color="green", end="\n", verbose=self.verbose
#     110 )
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\base.py:475, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     473     if len(args) != 1:
#     474         raise ValueError("`run` supports only one positional argument.")
# --> 475     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     476         _output_key
#     477     ]
#     479 if kwargs and not args:
#     480     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     481         _output_key
#     482     ]
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\base.py:282, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     280 except (KeyboardInterrupt, Exception) as e:
#     281     run_manager.on_chain_error(e)
# --> 282     raise e
#     283 run_manager.on_chain_end(outputs)
#     284 final_outputs: Dict[str, Any] = self.prep_outputs(
#     285     inputs, outputs, return_only_outputs
#     286 )
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\base.py:276, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     270 run_manager = callback_manager.on_chain_start(
#     271     dumpd(self),
#     272     inputs,
#     273 )
#     274 try:
#     275     outputs = (
# --> 276         self._call(inputs, run_manager=run_manager)
#     277         if new_arg_supported
#     278         else self._call(inputs)
#     279     )
#     280 except (KeyboardInterrupt, Exception) as e:
#     281     run_manager.on_chain_error(e)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\llm.py:92, in LLMChain._call(self, inputs, run_manager)
#      87 def _call(
#      88     self,
#      89     inputs: Dict[str, Any],
#      90     run_manager: Optional[CallbackManagerForChainRun] = None,
#      91 ) -> Dict[str, str]:
# ---> 92     response = self.generate([inputs], run_manager=run_manager)
#      93     return self.create_outputs(response)[0]
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chains\llm.py:102, in LLMChain.generate(self, input_list, run_manager)
#     100 """Generate LLM result from inputs."""
#     101 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 102 return self.llm.generate_prompt(
#     103     prompts,
#     104     stop,
#     105     callbacks=run_manager.get_child() if run_manager else None,
#     106     **self.llm_kwargs,
#     107 )
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chat_models\base.py:415, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     407 def generate_prompt(
#     408     self,
#     409     prompts: List[PromptValue],
#    (...)
#     412     **kwargs: Any,
#     413 ) -> LLMResult:
#     414     prompt_messages = [p.to_messages() for p in prompts]
# --> 415     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chat_models\base.py:310, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, **kwargs)
#     308         if run_managers:
#     309             run_managers[i].on_llm_error(e)
# --> 310         raise e
#     311 flattened_outputs = [
#     312     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     313     for res in results
#     314 ]
#     315 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chat_models\base.py:300, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, **kwargs)
#     297 for i, m in enumerate(messages):
#     298     try:
#     299         results.append(
# --> 300             self._generate_with_cache(
#     301                 m,
#     302                 stop=stop,
#     303                 run_manager=run_managers[i] if run_managers else None,
#     304                 **kwargs,
#     305             )
#     306         )
#     307     except (KeyboardInterrupt, Exception) as e:
#     308         if run_managers:
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chat_models\base.py:447, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     443     raise ValueError(
#     444         "Asked to cache, but no cache found at `langchain.cache`."
#     445     )
#     446 if new_arg_supported:
# --> 447     return self._generate(
#     448         messages, stop=stop, run_manager=run_manager, **kwargs
#     449     )
#     450 else:
#     451     return self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chat_models\openai.py:340, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     338 message_dicts, params = self._create_message_dicts(messages, stop)
#     339 params = {**params, **kwargs}
# --> 340 response = self.completion_with_retry(
#     341     messages=message_dicts, run_manager=run_manager, **params
#     342 )
#     343 return self._create_chat_result(response)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chat_models\openai.py:279, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     275 @retry_decorator
#     276 def _completion_with_retry(**kwargs: Any) -> Any:
#     277     return self.client.create(**kwargs)
# --> 279 return _completion_with_retry(**kwargs)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\langchain\chat_models\openai.py:277, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     275 @retry_decorator
#     276 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 277     return self.client.create(**kwargs)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\openai\api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\openai\api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\luisk\Projects-Win\langchain-geo\venv\lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
